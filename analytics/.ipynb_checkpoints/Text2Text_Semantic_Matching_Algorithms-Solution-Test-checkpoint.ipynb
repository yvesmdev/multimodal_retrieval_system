# %% [markdown]
# <h1>Prompt Image Matching Process</h1>

# %%
import dill as pickle

with open('models/image_recommender_model_florence_long_word2vectfidf_files.pkl', 'rb') as f:
    system_image_recommender = pickle.load(f)
    sys_tagged_sample_df = pickle.load(f)
    text_preprocess = pickle.load(f)
    word2vec_model = pickle.load(f)
    sys_X_emb = pickle.load(f)
    sys_text2emb = pickle.load(f)
    sys_tfidf = pickle.load(f)
    sys_X_matrix = pickle.load(f)

# %%
from nltk.corpus import stopwords
import re
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity 

tagger = 'florence_long'
text_in = 'mango'
output_df = system_image_recommender(sys_tagged_sample_df,tagger,[],sys_X_emb,text_in,
                                     sys_text2emb,thr_=0.0,top_n=10)
output_df
# Out:
#                                 file_name  \
# 81   ebc06b4808dc4848b4b2840ab32712a7.jpg
# 416  00df6d73e4ea4dfd9c0b3e5c87ddec55.jpg
# 27   e6701c367a954086bd78c69c9f5ce0d3.jpg
# 197  a1a13161c77b4f2ebf79a579d78674d0.jpg
# 391  072d64f93c2848c88cff3a32604e78bd.jpg
# 86   327f4611b79543a89e5bb403590e2a22.jpg
# 72   d3df5764b8724aec88306dd0f1d00f91.jpg
# 135  36b71a034c064eb8bfe4caa337a0b9f8.jpg
# 23   3c516dc2a2934bcfa18f36d1c0b66c76.jpg
# 64   6c45f033fc2344f2af34a1e3503b786c.jpg
#
#                                          florence_long       sim
# 81   The image shows a whole cantaloupe melon and a...  0.628664
# 416  The image shows a white plate with sliced wate...  0.625866
# 27   The image is a flat lay of various fruits and ...  0.616102
# 197  The image is of a wooden bowl filled with a co...  0.602525
# 391  The image shows a roasted chicken on a black p...  0.591802
# 86   The image shows a plastic container with a pai...  0.585862
# 72   The image is a close-up of a bunch of fresh be...  0.585402
# 135  The image is a close-up of a salad in a black ...  0.584688
# 23   The image shows a woman standing in a kitchen,...  0.569380
# 64   The image is a close-up of a plate of fruit sa...  0.568866
