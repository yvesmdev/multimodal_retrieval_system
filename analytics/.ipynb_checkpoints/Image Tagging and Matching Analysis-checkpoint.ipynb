# %% [markdown]
# <h1>Multimodal Image Retrieving System</h1>

# %% [markdown]
# <h3>Step 1: Image dataset </h3>

# %%
import pandas as pd

img_df = pd.read_csv('../sample_images/sample_images.csv')
img_df.head()
# Out:
#                               file_name
# 0  4afccb317564489cab6f7d70985fdba0.jpg
# 1  dd696f3d76e84050a5050d9c80a0ec16.jpg
# 2  e25114803e2e4b69bf1c0ec3eef96142.jpg
# 3  ce77214244834cf38e9be5edec8c3eea.jpg
# 4  e38172f9991448fe84ff8b09a4fbf51a.jpg

# %%
print('Number of Images:',len(img_df))
# Out:
# Number of Images: 500

# %%
img_df.iloc[1].file_name
# Out:
# 'dd696f3d76e84050a5050d9c80a0ec16.jpg'

# %%
id = 0
image_name = img_df.iloc[id].file_name

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('../sample_images/'+image_name)
plt.figure()
plt.imshow(img)
plt.axis("off")
plt.show()
